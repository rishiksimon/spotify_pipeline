# %%
# %reload_ext sql
# %sql mysql+mysqlconnector://root:root@localhost/test

# %%
# %%sql
# create database spotify_db;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.DatabaseError) 1007 (HY000): Can't create database 'spotify_db'; database exists
# [SQL: create database spotify_db;]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
#
# use spotify_db;
# CREATE TABLE IF NOT EXISTS spotify_tracks (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     track_name VARCHAR(255),
#     artist VARCHAR(255),
#     album VARCHAR(255),
#     popularity INT,
#     duration_minutes FLOAT
# )
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# use spotify_db;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# truncate table spotify_tracks;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
import prettytable
print([name for name in prettytable.__dict__.keys() if name.isupper()])
# Out:
# ['_DEPRECATED_ALL', '_DEPRECATED_DEFAULT', '_DEPRECATED_DOUBLE_BORDER', '_DEPRECATED_FRAME', '_DEPRECATED_HEADER', '_DEPRECATED_MARKDOWN', '_DEPRECATED_MSWORD_FRIENDLY', '_DEPRECATED_NONE', '_DEPRECATED_ORGMODE', '_DEPRECATED_PLAIN_COLUMNS', '_DEPRECATED_RANDOM', '_DEPRECATED_SINGLE_BORDER']

# %%
# %config SqlMagic.style = "PLAIN_COLUMNS"

# %%
import prettytable
styles = [name for name in prettytable.__dict__.keys() if name.isupper()]
print(styles)
# Out:
# ['_DEPRECATED_ALL', '_DEPRECATED_DEFAULT', '_DEPRECATED_DOUBLE_BORDER', '_DEPRECATED_FRAME', '_DEPRECATED_HEADER', '_DEPRECATED_MARKDOWN', '_DEPRECATED_MSWORD_FRIENDLY', '_DEPRECATED_NONE', '_DEPRECATED_ORGMODE', '_DEPRECATED_PLAIN_COLUMNS', '_DEPRECATED_RANDOM', '_DEPRECATED_SINGLE_BORDER']

# %%
# %config SqlMagic.style = "MARKDOWN"

# %%
pip install --upgrade prettytable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import prettytable

# Find all available style constants in your prettytable version
styles = [name for name in prettytable.__dict__.keys() if name.isupper()]
print("Available styles:", styles)

# Pick the first available style automatically
if styles:
    chosen_style = styles[0]
    print("Using style:", chosen_style)

    # Apply it to SqlMagic
    # %config SqlMagic.style = chosen_style
else:
    print("No styles found in prettytable.__dict__")
# Out:
# Available styles: ['_DEPRECATED_ALL', '_DEPRECATED_DEFAULT', '_DEPRECATED_DOUBLE_BORDER', '_DEPRECATED_FRAME', '_DEPRECATED_HEADER', '_DEPRECATED_MARKDOWN', '_DEPRECATED_MSWORD_FRIENDLY', '_DEPRECATED_NONE', '_DEPRECATED_ORGMODE', '_DEPRECATED_PLAIN_COLUMNS', '_DEPRECATED_RANDOM', '_DEPRECATED_SINGLE_BORDER']
# Using style: _DEPRECATED_ALL

# %%
# %%sql
# select * from spotify_db.spotify_tracks;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 10 rows affected.
# [(1, 'Mr. Brightside', 'The Killers', 'Hot Fuss', 91, 3.71622),
#  (2, 'Mr. Brightside', 'The Killers', 'Hot Fuss', 63, 3.70333),
#  (3, 'Time is Running Out', 'Muse', 'Absolution', 3, 3.95065),
#  (4, 'Uprising', 'Muse', 'The Resistance', 78, 5.08067),
#  (5, 'Despacito', 'Luis Fonsi', 'VIDA', 82, 3.82267),
#  (6, 'Mr. Brightside', 'The Killers', 'Hot Fuss', 7, 3.70125),
#  (7, 'Lover', 'Taylor Swift', 'Lover', 84, 3.68843),
#  (8, 'Shape of You', 'Ed Sheeran', '÷ (Deluxe)', 89, 3.8952),
#  (9, 'Every Breath You Take', 'The Police', 'Synchronicity (Remastered 2003)', 94, 4.232),
#  (10, 'Prelude for Piano No. 11 in F-Sharp Minor', 'Eduard Abramyan', 'Abramyan: Preludes – Rachmaninoff: Sonata No. 2 in B-Flat Minor, Op. 36 – Babadjanyan: Capriccio, Improvisation, Folksong, Elegy, Poem', 26, 4.13822)]

# %%
# %%sql
# SELECT track_name, artist, album, popularity
# FROM spotify_tracks
# ORDER BY popularity DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [('Every Breath You Take', 'The Police', 'Synchronicity (Remastered 2003)', 94)]

# %%
# %%sql
# SELECT AVG(popularity) AS average_popularity
# FROM spotify_tracks;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(Decimal('61.7000'),)]

# %%
# %%sql
# SELECT track_name, artist, duration_minutes
# FROM spotify_tracks
# WHERE duration_minutes > 4.0;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('Uprising', 'Muse', 5.08067),
#  ('Every Breath You Take', 'The Police', 4.232),
#  ('Prelude for Piano No. 11 in F-Sharp Minor', 'Eduard Abramyan', 4.13822)]

# %%
# %%sql
# SELECT
#     CASE
#         WHEN popularity >= 80 THEN 'Very Popular'
#         WHEN popularity >= 50 THEN 'Popular'
#         ELSE 'Less Popular'
#     END AS popularity_range,
#     COUNT(*) AS track_count
# FROM spotify_tracks
# GROUP BY popularity_range;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('Very Popular', 5), ('Popular', 2), ('Less Popular', 3)]
